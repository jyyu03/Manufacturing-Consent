# %%
# Chrome Driver and Imports
from splinter import Browser
from bs4 import BeautifulSoup as bs
import pandas as pd
import prettify
import requests
import requests
import time
from citipy import citipy
import json
import tweepy
import datetime
from config import consumer_key, consumer_secret, access_token, access_token_secret
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
print(datetime.datetime.now())
# Out:
# 2018-11-30 21:01:17.466028

# %%
from flask import Flask, jsonify, render_template
import pymongo
#set up connection to mlab
app = Flask(__name__)
DB_NAME = 'manufacture_consent'
DB_HOST = 'ds255403.mlab.com'
DB_PORT =  55403
DB_USER = 'edwardwisejr'
DB_PASS = 'Flender77!'
connection = pymongo.MongoClient(DB_HOST, DB_PORT)
db = connection[DB_NAME]
db.authenticate(DB_USER, DB_PASS)

# news_collection = db['mc_daily_state_news']
# news_collection.insert_one(*****item).inserted_id
# Out:
# True

# %%
# tweets_collection = db['mc_tweets']
# tweets_df=pd.DataFrame(list(tweets_collection.find({})))

# %%
# tweets_df.head()

# %%
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)

# %%
## ENTER STATE
state = 'IN'

# %%
#####BROWSER####
url = f"https://www.stationindex.com/tv/by-state/{state}"
browser.visit(url)
html=(browser.html)
soup = bs(html, 'html.parser')
soup.encode("utf-8")
pretty = soup.prettify
links = soup.find_all('a')
callsigns = []
markets = []
urls = []
# get the links from the 
for link in links:
    if "tv/callsign" in link['href']:
        callsigns.append(link.string)
        urls.append(link['href'])
#         print(link.string)
    elif "tv/markets" in link['href']:
        markets.append(link.string)
stations = pd.DataFrame({
    "Callsign": callsigns,
    "Market": markets,
    "URL": urls
})
## GET WEBSITES FOR EACH LOCAL STATION IN THE STATE
page_twitters = []
website_links = []
station_urls = stations['URL']
for station in station_urls:
    url = station
    browser.visit(url)
    html=(browser.html)
    soup = bs(html, 'html.parser')
    soup.encode("utf-8")
    links = soup.find_all('a')
    page_links=[]
    for link in links:
        page_links.append(link.text)
        if "http" in link.text:
            website_links.append(link.text)
website_links
# Out:
# ['http://www.wane.com/',
#  'http://www.mywabashvalley.com/',
#  'http://www.tbn.org/',
#  'http://www.abc25.com/',
#  'http://www.wevv.com/',
#  'http://www.wevv.com/',
#  'http://www.wfft.com/',
#  'http://www.14wfie.com/',
#  'http://www.wmyo.com/',
#  'http://www.wfwa.org/',
#  'http://www.wfyi.org/',
#  'https://whmbtv40.com/',
#  'https://whmetv46.com/',
#  'http://www.bsu.edu/wipb/',
#  'http://www.wise33.com/',
#  'http://www.wishtv.com/',
#  'http://www.jwsim.org/wjyl45/',
#  'http://www.wjystv62.net/',
#  'http://www.tbn.org/',
#  'http://www.wlfi.com/',
#  'http://www.thecw25.com/',
#  'http://www.mymichianatv.com/',
#  'http://www.indiana9.com/',
#  'http://www.wndu.com/',
#  'http://www.wndy.com/',
#  'http://www.wnin.org/',
#  'http://www.wnit.org/',
#  'http://www.wpta.com/',
#  'http://www.fox32chicago.com/cw50chicago',
#  'http://www.theindychannel.com/',
#  'http://www.wsbt.com/',
#  'http://www.fox28.com/',
#  'http://www.wthitv.com/',
#  'http://www.wthr.com/',
#  'http://www.indiana.edu/~radiotv/wtiu/',
#  'http://www.indianas4.com/',
#  'http://www.indianas4.com/',
#  'http://www.tristatehomepage.com/',
#  'http://www.wtwo.com/',
#  'http://www.fox59.com/']

# %%
# # ## New Headless Driver if needed
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=True)

# %%
## GET EVERY STATION'S LINKS WITH A FILTER
times = []
websites = []
states = []
link_texts = []
buzz_words = []
twitter_links = []
daily_news = db.mc_daily_state_news
for link in website_links:
    browser.visit(link)
    html=(browser.html)
    soup = bs(html, 'html.parser')
    soup.encode("utf-8")
    links = soup.find_all('a')
    for l in links:
        if "Trump" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "Trump",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        elif "migrant" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "migrant",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        elif "email" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "email",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
        elif "Mueller" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "Mueller",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        elif "Democrat" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "Democrat",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        elif "Republican" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "Republican",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        else:
            continue
# Out:
# Link Text on http://www.wane.com/ :  3 dead, 8 injured in immigrant smuggling attempt at border
# Link Text on http://www.wane.com/ :  3 dead, 8 injured in immigrant smuggling attempt at border
# Link Text on http://www.wfft.com/ : Google CEO to appear before Congress where he will likely face questions from Republicans on political bias
# Link Text on http://www.wfft.com/ : Democrats vote to nominate Nancy Pelosi for House speaker
# Link Text on http://www.wfft.com/ : Ivanka Trump says 'no equivalency' between her email use and Clinton's
# Link Text on http://www.14wfie.com/ :  US judge won't immediately allow Trump to enforce asylum ban
# Link Text on http://www.14wfie.com/ :  US judge won't immediately allow Trump to enforce asylum ban
# Link Text on http://www.14wfie.com/ :   Trump’s labor secretary criticized for negotiating wealthy sex offender’s plea deal
# Link Text on http://www.14wfie.com/ :  Trump: Moscow deal 'never went through'
# Link Text on http://www.14wfie.com/ :   Trump says pardon for Manafort ‘not off the table’
# Link Text on http://www.wfwa.org/ : On Russia, did Trump’s business and policy converge?
# Link Text on http://www.wfwa.org/ : Shields and Brooks on Mueller developments and congressional dynamics
# Link Text on http://www.wlfi.com/ : Democrats vote to nominate Nancy Pelosi for House speaker
# Link Text on http://www.thecw25.com/ : Trump signs NAFTA replacement deal ahead of the G20 summit
# Link Text on http://www.wndu.com/ : Farmers in America’s heartland eagerly awaiting outcome of Trump’s meeting with Xi
# Link Text on http://www.theindychannel.com/ :      <img alt="Cohen believed Trump would pardon him" src="https://sharing.scrippsnationalnews.com/sharescnn/photo/2018/09/20/1537484083_98160394_ver1.0_320_240.jpg" class="media" />    Cohen believed Trump would pardon him  Cohen was under the impression Trump would offer him a pardon in exchange for staying on…
# Link Text on http://www.theindychannel.com/ :  Mueller's team: Manafort could face more charges
# Link Text on http://www.wsbt.com/ : Trump allies distance themselves from Michael Cohen and Paul Manafort
# 5 hours ago
# Link Text on http://www.wsbt.com/ : Top StoryTrump's wins on trade, NATO spending come at a cost, experts say
#
# Link Text on http://www.wsbt.com/ : Trump invites Brazil President-elect Bolsonaro to visit US
# 1 day ago
# Link Text on http://www.fox28.com/ : Trump allies distance themselves from Michael Cohen and Paul Manafort
# 5 hours ago
# Link Text on http://www.fox28.com/ : Top StoryTrump's wins on trade, NATO spending come at a cost, experts say
#
# Link Text on http://www.fox28.com/ : Trump invites Brazil President-elect Bolsonaro to visit US
# 1 day ago
# Link Text on http://www.wthitv.com/ : Manafort-Mueller feud resumes in court Friday
# Link Text on http://www.wthitv.com/ : 5 things to know for November 30: Trump, mall shooting, measles, destroyed rape kits
# Link Text on http://www.wthitv.com/ : Trump abruptly cancels planned Putin meeting
# Link Text on http://www.wthr.com/ : Republican takes House race by 1 vote after recount

# %%
news = pd.DataFrame(list(daily_news.find({})))

# %%
news.head()
# Out:
#   Buzz Word                                          Link Text State  \
# 0     Trump  \n\t\t\t\tThe Latest: Coliseum decked out in C...    WI
# 1     Trump  \n\t\t\t\tThe Latest: Coliseum decked out in C...    WI
# 2  Democrat  \n\t\t\t\tDemocrat edges ahead in California U...    WI
# 3  Democrat  \n\t\t\t\tDemocratic presidential prospect Blo...    WI
# 4  Democrat  \n\t\t\t\tThe Latest: Democrat says recount de...    WI
#
#                      Time               Website                       _id
# 0 2018-11-26 22:25:54.378  http://www.kbjr.com/  5bfcc752b4042e414050fe25
# 1 2018-11-26 22:25:54.402  http://www.kbjr.com/  5bfcc752b4042e414050fe26
# 2 2018-11-26 22:25:54.436  http://www.kbjr.com/  5bfcc752b4042e414050fe27
# 3 2018-11-26 22:25:54.468  http://www.kbjr.com/  5bfcc752b4042e414050fe28
# 4 2018-11-26 22:25:54.492  http://www.kbjr.com/  5bfcc752b4042e414050fe29

# %%
import plotly
from plotly.offline import iplot, init_notebook_mode
import plotly.graph_objs as go