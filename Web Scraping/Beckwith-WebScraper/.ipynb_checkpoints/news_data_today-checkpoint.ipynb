# %%
# Chrome Driver and Imports
from splinter import Browser
from bs4 import BeautifulSoup as bs
import pandas as pd
import prettify
import requests
import requests
import time
from citipy import citipy
import json
import tweepy
import datetime
from config import consumer_key, consumer_secret, access_token, access_token_secret
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
print(datetime.datetime.now())
# Out:
# 2018-11-30 21:01:17.466028

# %%
from flask import Flask, jsonify, render_template
import pymongo
#set up connection to mlab
app = Flask(__name__)
DB_NAME = 'manufacture_consent'
DB_HOST = 'ds255403.mlab.com'
DB_PORT =  55403
DB_USER = 'edwardwisejr'
DB_PASS = 'Flender77!'
connection = pymongo.MongoClient(DB_HOST, DB_PORT)
db = connection[DB_NAME]
db.authenticate(DB_USER, DB_PASS)

# news_collection = db['mc_daily_state_news']
# news_collection.insert_one(*****item).inserted_id
# Out:
# True

# %%
# tweets_collection = db['mc_tweets']
# tweets_df=pd.DataFrame(list(tweets_collection.find({})))

# %%
# tweets_df.head()

# %%
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)

# %%
## ENTER STATE
state = 'IN'

# %%
#####BROWSER####
url = f"https://www.stationindex.com/tv/by-state/{state}"
browser.visit(url)
html=(browser.html)
soup = bs(html, 'html.parser')
soup.encode("utf-8")
pretty = soup.prettify
links = soup.find_all('a')
callsigns = []
markets = []
urls = []
# get the links from the 
for link in links:
    if "tv/callsign" in link['href']:
        callsigns.append(link.string)
        urls.append(link['href'])
#         print(link.string)
    elif "tv/markets" in link['href']:
        markets.append(link.string)
stations = pd.DataFrame({
    "Callsign": callsigns,
    "Market": markets,
    "URL": urls
})
## GET WEBSITES FOR EACH LOCAL STATION IN THE STATE
page_twitters = []
website_links = []
station_urls = stations['URL']
for station in station_urls:
    url = station
    browser.visit(url)
    html=(browser.html)
    soup = bs(html, 'html.parser')
    soup.encode("utf-8")
    links = soup.find_all('a')
    page_links=[]
    for link in links:
        page_links.append(link.text)
        if "http" in link.text:
            website_links.append(link.text)
website_links
# Out:
# ['http://www.wane.com/',
#  'http://www.mywabashvalley.com/',
#  'http://www.tbn.org/',
#  'http://www.abc25.com/',
#  'http://www.wevv.com/',
#  'http://www.wevv.com/',
#  'http://www.wfft.com/',
#  'http://www.14wfie.com/',
#  'http://www.wmyo.com/',
#  'http://www.wfwa.org/',
#  'http://www.wfyi.org/',
#  'https://whmbtv40.com/',
#  'https://whmetv46.com/',
#  'http://www.bsu.edu/wipb/',
#  'http://www.wise33.com/',
#  'http://www.wishtv.com/',
#  'http://www.jwsim.org/wjyl45/',
#  'http://www.wjystv62.net/',
#  'http://www.tbn.org/',
#  'http://www.wlfi.com/',
#  'http://www.thecw25.com/',
#  'http://www.mymichianatv.com/',
#  'http://www.indiana9.com/',
#  'http://www.wndu.com/',
#  'http://www.wndy.com/',
#  'http://www.wnin.org/',
#  'http://www.wnit.org/',
#  'http://www.wpta.com/',
#  'http://www.fox32chicago.com/cw50chicago',
#  'http://www.theindychannel.com/',
#  'http://www.wsbt.com/',
#  'http://www.fox28.com/',
#  'http://www.wthitv.com/',
#  'http://www.wthr.com/',
#  'http://www.indiana.edu/~radiotv/wtiu/',
#  'http://www.indianas4.com/',
#  'http://www.indianas4.com/',
#  'http://www.tristatehomepage.com/',
#  'http://www.wtwo.com/',
#  'http://www.fox59.com/']

# %%
# # ## New Headless Driver if needed
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=True)

# %%
## GET EVERY STATION'S LINKS WITH A FILTER
times = []
websites = []
states = []
link_texts = []
buzz_words = []
twitter_links = []
daily_news = db.mc_daily_state_news
for link in website_links:
    browser.visit(link)
    html=(browser.html)
    soup = bs(html, 'html.parser')
    soup.encode("utf-8")
    links = soup.find_all('a')
    for l in links:
        if "Trump" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "Trump",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        elif "migrant" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "migrant",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        elif "email" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "email",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
        elif "Mueller" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "Mueller",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        elif "Democrat" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "Democrat",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        elif "Republican" in l.text:
            print(f"Link Text on {link} : {l.text}")
            daily_state_news =  {
                "State": state,
                "Buzz Word": "Republican",
                "Website": link,
                "Time": datetime.datetime.now(),
                "Link Text": l.text
            }
            daily_news.insert_one(daily_state_news)
        else:
            continue
# Out:
# Link Text on http://www.wane.com/ :  3 dead, 8 injured in immigrant smuggling attempt at border
# Link Text on http://www.wane.com/ :  3 dead, 8 injured in immigrant smuggling attempt at border
# Link Text on http://www.wfft.com/ : Google CEO to appear before Congress where he will likely face questions from Republicans on political bias
# Link Text on http://www.wfft.com/ : Democrats vote to nominate Nancy Pelosi for House speaker
# Link Text on http://www.wfft.com/ : Ivanka Trump says 'no equivalency' between her email use and Clinton's
# Link Text on http://www.14wfie.com/ :  US judge won't immediately allow Trump to enforce asylum ban
# Link Text on http://www.14wfie.com/ :  US judge won't immediately allow Trump to enforce asylum ban
# Link Text on http://www.14wfie.com/ :   Trump’s labor secretary criticized for negotiating wealthy sex offender’s plea deal
# Link Text on http://www.14wfie.com/ :  Trump: Moscow deal 'never went through'
# Link Text on http://www.14wfie.com/ :   Trump says pardon for Manafort ‘not off the table’
# Link Text on http://www.wfwa.org/ : On Russia, did Trump’s business and policy converge?
# Link Text on http://www.wfwa.org/ : Shields and Brooks on Mueller developments and congressional dynamics
# Link Text on http://www.wlfi.com/ : Democrats vote to nominate Nancy Pelosi for House speaker
# Link Text on http://www.thecw25.com/ : Trump signs NAFTA replacement deal ahead of the G20 summit
# 14   5bfcc789b4042e414050fe33
# 15   5bfcc789b4042e414050fe34
# 16   5bfcc789b4042e414050fe35
# 17   5bfcc789b4042e414050fe36
# 18   5bfcc78ab4042e414050fe37
# 19   5bfcc798b4042e414050fe38
# 20   5bfcc7bab4042e414050fe39
# 21   5bfcc7bab4042e414050fe3a
# 22   5bfcc7bab4042e414050fe3b
# 23   5bfcc7bab4042e414050fe3c
# 24   5bfcc7d4b4042e414050fe3d
# 25   5bfcc7d4b4042e414050fe3e
# 26   5bfcc7d4b4042e414050fe3f
# 27   5bfcc7d4b4042e414050fe40
# 28   5bfcc7d4b4042e414050fe41
# 29   5bfcc7d4b4042e414050fe42
# ..                        ...
# 904  5c01fda8b4042e5cb89e5022
# 905  5c01fda8b4042e5cb89e5023
# 906  5c01fdadb4042e5cb89e5024
# 907  5c01feb1b4042e5cb89e5025
# 908  5c01feb1b4042e5cb89e5026
# 909  5c01fee4b4042e5cb89e5027
# 910  5c01fee4b4042e5cb89e5028
# 911  5c01fee4b4042e5cb89e5029
# 912  5c01fee8b4042e5cb89e502a
# 913  5c01fee8b4042e5cb89e502b
# 914  5c01fee8b4042e5cb89e502c
# 915  5c01fee8b4042e5cb89e502d
# 916  5c01fee8b4042e5cb89e502e
# 917  5c01fef8b4042e5cb89e502f
# 918  5c01fef8b4042e5cb89e5030
# 919  5c01ff2eb4042e5cb89e5031
# 920  5c01ff31b4042e5cb89e5032
# 921  5c01ffa9b4042e5cb89e5033
# 922  5c01ffcdb4042e5cb89e5034
# 923  5c01ffcdb4042e5cb89e5035
# 924  5c01ffd1b4042e5cb89e5036
# 925  5c01ffd1b4042e5cb89e5037
# 926  5c01ffd1b4042e5cb89e5038
# 927  5c01ffd4b4042e5cb89e5039
# 928  5c01ffd4b4042e5cb89e503a
# 929  5c01ffd4b4042e5cb89e503b
# 930  5c01ffdfb4042e5cb89e503c
# 931  5c01ffdfb4042e5cb89e503d
# 932  5c01ffdfb4042e5cb89e503e
# 933  5c01ffeeb4042e5cb89e503f
#
# [934 rows x 6 columns]

# %%
import plotly
from plotly.offline import iplot, init_notebook_mode
import plotly.graph_objs as go
import plotly.io as pio
init_notebook_mode(connected=True)
buzz_words = news['Buzz Word']
date_times = news['Time']
website_urls = news['Website']
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
N = 100
fig = go.Figure()
fig.add_scatter(x=website_urls,
                y=buzz_words,
                mode='markers',
                fillcolor="black",
                hovertext= buzz_words,
                marker={'size': 8,
                        'color': "red",
                        'opacity': 0.5,
                        'colorscale': 'Viridis'
                       });
iplot(fig)
# Out:
# <div id="d50a7bf3-0783-47d3-a243-0089c688129e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d50a7bf3-0783-47d3-a243-0089c688129e", [{"fillcolor": "black", "hovertext": ["Trump", "Trump", "Democrat", "Democrat", "Democrat", "Trump", "Democrat", "Trump", "Trump", "Trump", "Trump", "Democrat", "Trump", "Trump", "Trump", "Trump", "Trump", "Trump", "Trump", "Trump", "Trump", "migrant", "migrant", "Trump", "Trump", "Trump", "Trump", "Trump", "Mueller", "Trump", "Trump", "Trump", "Trump", "Trump", "Trump", "Trump", "Democrat", "Trump", "Trump", "Trump", "Mueller", "Trump", "Trump", "migrant", "Republican", "Democrat", "Trump", "Trump", "Mueller", "Trump", "Trump", "Trump",